# %% [markdown]
# # 서울시 구별 CCTV/인구 분석

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['axes.unicode_minus'] = False
mpl.rcParams['font.family'] = 'Malgun Gothic'

# %%
df = pd.read_csv('../02.Pandas/cctv_pop.csv', index_col='구별')
df.head(3)
# Out:
#      CCTV댓수  최근증가율     인구수     내국인    외국인    고령자  외국인비율  고령자비율
# 구별
# 종로구    1715  20.69  153789  144683   9106  27818   5.92  18.09
# 중구     2447  78.98  131787  122499   9288  24392   7.05  18.51
# 용산구    2611  78.64  237285  222953  14332  39070   6.04  16.47

# %% [markdown]
# - 상관관계 분석
#     - CCTV 댓수 vs. 인구수, 외국인비율, 고령자비율

# %%
# CCTV 댓수 vs. 인구수 
# 분포되어 있는 점을 가장 잘 표현하는 회귀선(regression)
# 인공지능 지도학습(분류+회귀)
sns.regplot(x='인구수', y='CCTV댓수', data=df)
plt.show()

# %%
_, axs = plt.subplots(1, 3, figsize=(15,5))
features = ['인구수', '외국인비율', '고령자비율']
for i, feature in enumerate(features):
    sns.regplot(x=feature, y='CCTV댓수', data=df, ax=axs[i])

# %% [markdown]
# - 구별 CCTV 댓수

# %%
# 인덱스를 잘 쓰면 그래프도 쉽게 그릴 수 있음
df.CCTV댓수.plot(kind='barh')
plt.title('구별 CCTV 댓수')
plt.show()

# %%
df.CCTV댓수.sort_values().plot(kind='barh', grid=True, figsize=(12,6))
plt.title('구별 CCTV 댓수', fontsize=15)
plt.show()

# %% [markdown]
# - 인구대비 CCTV 비율 시각화

# %%
# 인구 천명당 CCTV 댓수
df['CCTV비율'] = (df.CCTV댓수 / (df.인구수/1000)).round(2)
df.CCTV비율.sort_values().plot(kind='barh', grid=True, figsize=(12,6))
plt.title('구별 인구 천명당 CCTV 댓수', fontsize=15)
plt.show()

# %% [markdown]
# ### 인구수와 CCTV 댓수 분석
# - 산점도(Scatter plot)

# %%
plt.scatter(x=df.인구수, y=df.CCTV댓수)
plt.title('인구수와 CCTV 댓수의 산점도')
plt.xlabel('인구수'), plt.ylabel('CCTV댓수')
plt.grid(); plt.show()

# %% [markdown]
# - 회귀선

# %%
weight, bias = np.polyfit(df.인구수, df.CCTV댓수, 1)     # x, y, 차수(1차원)
weight, bias
# Out:
# (0.004085429243410675, 1751.246023182563)

# %%
x = np.array([100000, 700000])
y = weight * x + bias
y
# Out:
# array([2159.78894752, 4611.04649357])

# %%
plt.figure(figsize=(6,6))
plt.scatter(x=df.인구수, y=df.CCTV댓수)
plt.plot(x, y, 'g--', lw=3)         # green(g), dashed(--)
plt.title('인구수와 CCTV 댓수의 산점도')
plt.xlabel('인구수'), plt.ylabel('CCTV댓수')
plt.grid(); plt.show()

# %% [markdown]
# - 회귀선과 산점도 사이의 절대오차 (residual error, 잔차)

# %%
df['오차'] = abs(df.CCTV댓수 - (df.인구수*weight + bias)).round(2)
df_sort = df.sort_values(by='오차', ascending=False)
df_sort.head(10)
# Out:
#      CCTV댓수   최근증가율     인구수     내국인    외국인    고령자  외국인비율  고령자비율  CCTV비율  \
# 구별
# 강남구    6871   63.24  537800  533042   4758  78226   0.88  14.55   12.78
# 송파구    2897  204.31  663965  658338   5627  97691   0.85  14.71    4.36
# 강서구    2744   79.11  579768  574315   5453  92558   0.94  15.96    4.73
# 노원구    2492   68.47  514946  510956   3990  88345   0.77  17.16    4.84
# 관악구    5149   48.29  499449  485699  13750  79871   2.75  15.99   10.31
# 구로구    4608   48.83  421163  396754  24409  72611   5.80  17.24   10.94
# 도봉구    1930   85.44  319373  317366   2007  64160   0.63  20.09    6.04
# 동작구    2306   83.61  394364  385483   8881  66613   2.25  16.89    5.85
# 성북구    4602   77.58  440142  430528   9614  74709   2.18  16.97   10.46
# 성동구    3829   63.49  292672  285990   6682  46380   2.28  15.85   13.08
#
#           오차
# 구별
# 강남구  2922.61
# 송파구  1566.83
# 강서구  1375.85
# 노원구  1363.02
# 관악구  1357.29
# 구로구  1136.12
# 도봉구  1126.02
# 동작구  1056.39
# 성북구  1052.58
# 성동구   882.06

# %%
plt.figure(figsize=(12,8))
plt.scatter(x=df.인구수, y=df.CCTV댓수, c=df.오차, s=50)
plt.plot(x, y, 'g--', lw=3)         # green(g), dashed(--)
plt.title('인구수와 CCTV 댓수의 산점도')
plt.xlabel('인구수'), plt.ylabel('CCTV댓수')
plt.colorbar()
plt.grid(); plt.show()

# %%
plt.figure(figsize=(12,8))
plt.scatter(x=df.인구수, y=df.CCTV댓수, c=df.오차, s=50)
plt.plot(x, y, 'g--', lw=3)
for i in range(10):
    plt.text(df_sort.인구수[i], df_sort.CCTV댓수[i], 
                df_sort.index[i], fontsize=15)
plt.title('인구수와 CCTV 댓수의 산점도')
plt.xlabel('인구수'), plt.ylabel('CCTV댓수')
plt.colorbar()
plt.grid(); plt.show()
